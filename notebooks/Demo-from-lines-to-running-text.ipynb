# %% [markdown]
# # Turning text lines into running text elements
#
# **Note**: This tutorial follows and depends on the tutorial on [Reading PageXML files from archives](./Demo-reading-pagexml-files-from-archive.ipynb). It assumes you have downloaded the PageXML archives and derived line format files from them.
#
# PageXML documents contain text lines as represented in the **physical document**, but these lines do not correspond one-to-one with sentences and paragraphs of the **logical structure** of the document.
#
# Turning lines of text into running paragraphs of text requires taking into account paragraph boundaries and word-break characters like soft-hyphens ('-').
#
# As an example of a text archive, this tutorial uses a dataset provided by the [National Archives of the Netherlands](https://www.nationaalarchief.nl/en) (NA) via their HTR repository on [Zenodo](https://zenodo.org/): https://zenodo.org/record/6414086#.Y8Elk-zMIUo. The repository contains many other HTR PageXML datasets that NA made available.
#
# The dataset contains HTR output in [PageXML](https://www.primaresearch.org/tools/PAGELibraries) format of scans from the following archive:
# - (medium) _Verspreide West-Indische stukken, 1614-1875, 1.05.06, 1-1413_ ([EAD](https://www.nationaalarchief.nl/onderzoeken/archief/1.05.06/invnr/%401?query=1.05.06&search-type=inventory)). This is an archive maintained by the [Nationaal Archief](https://www.nationaalarchief.nl/en).
#
# You can download the datasets via the following URLs:
# - https://zenodo.org/record/6414086/files/HTR%20results%201.05.06%20PAGE.zip?download=1

# %% [markdown]
# ## Detecting word break characters
#
# **Note**: This tutorial follows and depends on the tutorial on [Reading PageXML files from archives](./Demo-reading-pagexml-files-from-archive.ipynb). It assumes you have downloaded the PageXML archives and derived line format files from them.
#
# This tutorials shows how you can check whether lines contain a word-break character (a word is split across the end of one line and the start of the next line, usually with a soft hyphen).

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pagexml.helper.text_helper as text_helper

da_line_file = '../data/line_format-NL-AsnDA_0114.11.tsv.gz'
na_line_file = '../data/line_format-NL-HaNA_1.05.06.tsv.gz'

# reading from line file is much faster 
# than reading from archived PageXML files
line_reader = text_helper.LineReader(pagexml_line_files=na_line_file, add_bounding_box=True)

# %% [markdown]
# The `text_stats` package contains class for analysing character and word frequencies and for detecting word-break characters and the _end_ and the _beginning_ of text lines.
#
# We start with analysing character frequencies in four different categories:
#
# - `all`: the overall frequency of characters
# - `start`: the frequency of characters that appear as the first character of a line
# - `end`: the frequency of characters that appear as the last character of a line
# - `mid`: the frequency of characters that appear between the first and last characters of a line
#
# This allows us to calculate relative frequencies of character in the start, middle and end of lines.
#
# The `LineCharAnalyser` takes as argument a iterable of text lines (which can be a list of strings, a list of `PageXMLTextLine`s or a list of dictionaries with a `text` property (e.g. from line-format files).

# %%
from pagexml.analysis.text_stats import LineCharAnalyser

lca = LineCharAnalyser(line_reader)

# %%
import pandas as pd

char_df = pd.DataFrame(lca.get_stats())
char_df.head(5)
# Out:
#   token_type  all_freq  all_frac  start_freq  start_frac  start_rel_frac  \
# 0          e   5630529  0.165220       30123    0.030213        0.182865
# 1              4849265  0.142295           0    0.000000        0.000000
# 2          n   2894479  0.084935       21729    0.021794        0.256597
# 3          a   2026303  0.059459       27859    0.027942        0.469940
# 4          o   1710173  0.050183       25457    0.025533        0.508802
#
#    mid_freq  mid_frac  mid_rel_frac  end_freq  end_frac  end_rel_frac
# 0   5462615  0.169998      1.028917    137791  0.145274      0.879274
# 1   4849265  0.150910      1.060545         0  0.000000      0.000000
# 2   2700582  0.084043      0.989500    172168  0.181518      2.137149
# 3   1986422  0.061818      1.039672     12022  0.012675      0.213169
# 4   1669379  0.051951      1.035247     15337  0.016170      0.322220

# %%
min_freq = char_df.all_freq.sum() / 1e4


char_df[char_df.all_freq > min_freq].sort_values('end_rel_frac', ascending=False).head(5)
# Out:
#    token_type  all_freq  all_frac  start_freq  start_frac  start_rel_frac  \
# 29          -    122764  0.003602        3588    0.003599        0.998994
# 31          „     97019  0.002847       38243    0.038357       13.473387
# 24          .    182205  0.005347        1056    0.001059        0.198100
# 75          ½      3578  0.000105         125    0.000125        1.194129
# 62          —     23118  0.000678        8739    0.008765       12.920910
#
#     mid_freq  mid_frac  mid_rel_frac  end_freq  end_frac  end_rel_frac
# 29     36817  0.001146      0.318058     82359  0.086832     24.104202
# 31     14227  0.000443      0.155520     44549  0.046968     16.498098
# 24     99568  0.003099      0.579547     81581  0.086011     16.087237
# 75      2014  0.000063      0.596964      1439  0.001517     14.450177
# 62      7103  0.000221      0.325852      7276  0.007671     11.308244

# %% [markdown]
# The hyphen `-`, low quotes `„` and period `.` are far more common as the last character of a line than letters like `e`, `n`, `a` and `o`.
#
# Both the hyphen and low quotes are typical word-break characters in hand-written text.

# %%
prev_line = None
for li, line in enumerate(line_reader):
    if prev_line is None or (prev_line['text'] is None or prev_line['text'] == ''):
        prev_line = line
        continue
    if prev_line is not None and prev_line['text'][-1] in {'-', '„'}:
        print(f"{prev_line['text']}   {line['text']}\n")
    if (li+1) >= 30:
        break
    prev_line = line
# Out:
# Monisen, reeders van den schepe ge„   naempt het Vosken, daer schipper op is
#
# geweest Jan de With, Hans Hongers, Pau„   lus Pelgrom, Lambrecht van Tweenhuijsen
#
# Claessen ende Berent Sweertssen, ree„   ders van het schip genaempt den

# %%
prev_line = None
for li, line in enumerate(line_reader):
    if prev_line is None or (prev_line['text'] is None or prev_line['text'] == ''):
        prev_line = line
        continue
    if prev_line is not None and prev_line['text'][-1] in {'-'}:
        print(f"{li}\t{prev_line['text']}   {line['text']}\n")
    if (li+1) >= 5000:
        break
    prev_line = line
# Out:
# 1510	een reijs van 16/m het eene door het andere d:o ƒ 24000-   aan Equipagien proncen uijt onthuijs komende maandgelden
#
# 3148	de en Horissante staat te brengen, zouden hoofdzaakelyk be-   staan:
#
# 3151	van Magellaan, om aldaar eene algemeene Laad- en Los-   plaats voor de schepen te hebben, en van de Producten
#
# 3161	Ten derden, in de Nieuwe Carolynsche Pilanden, mids-   Laders de Goud- en Parel-Filanden,
#
# 3164	Mirlofte buldekt zyn, en alle andere Pilanden, in de Zuid-   zoe gelegen, op eene veilige wyze, op te zoeken, en te
#
# 3169	met de Vrugten, Planten en Gewasschen, die deeze Lan-   den geeven, of aldaar met goed succes zouden kunnen ge-
#
# 3170	den geeven, of aldaar met goed succes zouden kunnen ge-   zaaid en geplant worden; midsgaders met der zelver andere
#
# 3172	Produelen, een voordeeligen Handel, zoo in Europa, als el-   ders, te dryven; en daar tegen weer Europische en andere
#
# 3176	Manschap konnen bevaaren worden, en weinig geld aan in-   koop en onderhoud kosten, tot het transporteeren der goe.
#
# 3186	Alle andere Middelen, waar van in dit Project zal wor-   den gesprooken, kunnen tot de bovengemelde hoofd-poinc
#
# 3190	voorgesteld; en teffens aantoonen, hoedanig de bovenge-   melde Middelen tot herstelling van de Westindische Maat
#
# 3197	Het kakstr werk zoudan behooren te weezen het aanleg-   gen van een Volkplanting op de Kust van Magellaan, in de
#
# 3216	het smelten van de Sneeu van de kruinen der Bergen op ver-   scheide plaatsen zoet water loopt. Men heeft 'er overvloed
#
# 3220	palmen hoog: aan de kop en langen hals gelyken zy na een Ca-   meel; dog over het overig gedeelte van tlighaam gelyken zy
#
# 3224	wol is, verwonderlyk syn Verders vindt men er Struisvo-   gels by twintigen teffens, Haazen, Patryzen, snippen, wil-
#
# 3225	gels by twintigen teffens, Haazen, Patryzen, snippen, wil-   de Ganzen, en een menigte klein Gevogelte. Men ontdekt
#
# 3232	heeft men het Pinguynen Piland, waar op zich een onbezel-   baare menigte van Pinquyns en Zeehalven onthouden. Na
#
# 3251	bladen en blaauwen bloessem, van den zelfden smaak als on-   ze groene Boonen. Onder verscheide groene Kruiden ont
#
# 3266	zoo dra zy daar toe gelegentheid konden vinden. Ziet ver-   ders de Reizen van de Capiteins John Warborough en Wood
#
# 3270	De schepen, die de Maatschappy van nooden zou heb-   ben,
#
# 3272	ben, om het bovengemelde Ontwerp (namentlyk van ’t aan-   leggen van een Volkplanting op de Kust van Magellaan) ter
#
# 3290	ze een Houtpoort hebben, en over de hut een galg, om stoe-   pen aan te hangen. Hetdek van de Kajuit moest zoo laag
#
# 3314	welke men gevangen kreeg. Van welke Dieren men aange-   zien haare groote, meenigte, en fyne wol, zeer groote voor-
#
# 3315	zien haare groote, meenigte, en fyne wol, zeer groote voor-   deelen zou kunnen trekken, voornamelyk wanneer men daar
#
# 3329	zou men met twee van de voorzeide kleine Hekboots kun-   nen laaten haalen; het zy van de vaste Kust, of van de Pi-
#
# 3330	nen laaten haalen; het zy van de vaste Kust, of van de Pi-   tanden, daar men het zelve het digtste- by zou vinden. De
#
# 3334	Zoetwaters Baai in de straat Magellaan is bezoomd met ge-   boomte, den beuken niet ongelyk, niet min dan 18 duimen
#
# 3336	over kruis dit, en veertig voeten hoog. - Dog nergens le-   verd die straat betere nog dikkere stammen, als by de Hon-
#
# 3337	verd die straat betere nog dikkere stammen, als by de Hon-   gerhaven, vindende men 'er van twee en een halve voeten
#
# 3356	siderabel veel geld zou uitwinnen, dat ze anders aan Victua-   sie voor ’t scheepsvolk zou moeten besteeden: behalven de
#
# 3358	onkosten van die Victualie uit Europa daar na toe te bren-   B 2
#
# 3363	’t geen men op de uit-reis van nooden hadt, moest mede nee-   men) men nu andere Waaren zou kunnen laaden.
#
# 3367	Wilden van deeze Kust, welke tot het Christen geloot wier-   den bekeerd, als Matroosen tot de Walvischvangst enz. ge-
#
# 3368	den bekeerd, als Matroosen tot de Walvischvangst enz. ge-   bruikte: alzoo de Maatschappy, die voor vry wat minder
#
# 3376	men die soldaaten en Matroosen, onder Europeaansche Sol-   daaten en Matrgosen vermengen, zoo liep men geen gevaar
#
# 3378	van door hun overweldigd te worden, of dat ze de sche-   pen zouden afloopen. En om hun niet alleen de hoop om
#
# 3381	doen, te beneemen, moest men hen weldoen, en heusche-   lik handelen.
#
# 3394	voor ’t volk van nooden hadt. Het vet daar van zou, ge-   lik gezegd is, kunnen dienen, om in plaats van Lamp- en
#
# 3414	5. Juliaan behooren te zenden. Deeze groote en kleine Hek-   boots moesten tot de Walvisch-vangst weezen uitgerust.
#
# 3417	Na dat het volk van de zelve zich in de Haven van 5. Ju-   siaan behoorlyk ververscht hadt, moest men twee van de
#
# 3421	laaten vertrekken, om de Walvischvangst daar in de Zomer-   maanden te pleegen. Men moest het spek, dat aldaar ge-
#
# 3422	maanden te pleegen. Men moest het spek, dat aldaar ge-   vangen wierdt, op het Piland Perre de Veutot Praan koo-
#
# 3423	vangen wierdt, op het Piland Perre de Veutot Praan koo-   ken: ten welken einde men ketels en andere noodige mate-
#
# 3424	ken: ten welken einde men ketels en andere noodige mate-   rialen moest medeneemen.
#
# 3436	de schepen met het overige spek en Praan na de Slaven 5. Ju-   liaan zeilen, en lossen daar haare Waaren aan land.
#
# 3441	Dat gedaan zynde, moesten de voorschreve groote Hek-   poots, om niet stil te leggen, van de slaven 5. Juliaan na
#
# 3443	de Kust van Atrica vertrekken, om aldaar in de Wintermaan-   den, tusschen de 1i en 28 graden Zuiderbreedte, mede de
#
# 3445	Walvischvangst te pleegen. Men moest daar niet op hoo-   ger breedte als van 28 graden, de Walvischvangst pleegen,
#
# 3451	den gekookt. Zy moesten daar in Augustus maaken te wee-   zen; om in de Maand September of October, weer, als voo-
#
# 3452	zen; om in de Maand September of October, weer, als voo-   ren, na Perre de feu te vertrekken, en aldaar de Walvisch
#
# 3461	gen, die men van nooden zou hebben, in de slaven amp. Jn-   siaan weer te rug. Van waarze in de Zomer-maanden weer
#
# 3471	den gekookt; In de Winter-maanden konden deeze sche-   pen, ook onder de Kust van Atrica gaan visschen. En duskon
#
# 3480	gebruiken, als de zelve na bevinding zou oordeelen te be-   hooren.
#
# 3485	van de Reizigers, die daar geweest zyn. Mij is van een ge-   looswaardig man verzekerd, dat de zelve twee Reizen van
#
# 3489	in een Baai, als ontakeld, hebben gelegen, en daar de Wat-   visschen gevangen; en dat in zoon groote menigte, dat zy
#
# 3505	den kunnen werden voorzien Capitein Warborough ge-   tuigd in de straat Magellaan verscheide Walvisschen te heb-
#
# 3506	tuigd in de straat Magellaan verscheide Walvisschen te heb-   ben gezien digte by de Caap Calant in zekere Baas, die hy
#
# 3512	der Reizen het 18 Deel Pag. 200 en de Reize van den Ad-   gemelde 18 Deel te vinden,
#
# 3534	van nooden hadt, met Praan, en andere Waaren na West-   Indie, de Kust van Cuuine, of Europa kunnen vertrekken.
#
# 3545	schooven moet worden meegenoomen, op dat de sche-   pen verders met andere goederen konden werden gelaaden.
#
# 3547	En op de weerom, reis van de Kust van Magellaan na Luro-   pa, zoumen op die schepen, tusschen het vaatwerk eenige
#
# 3550	geen hinder aan doen kon; ten einde dus maar weinig sche-   pen tot het transporteeren der goederen van nooden te hebben.
#
# 3555	die Jaarlyks uit Europa na de slaven 5. Juliaan zouden wer-   den gezonden, om de Praan daar van daan te haalen, zou
#
# 3560	zoete Oly, en eenige Plantjes van Vrugtboomen, in te nee-   men en vervolgens na de Kust van Magellaan te brengen.
#
# 3563	zoo dra de Walvisch-vangst gereguleerd was, of wan-   neer
#
# 3577	trekken, is, om het Vaarwater tusschen Diemen, en Nieuw-   Zeeland, zoo veel te beter te leeren kennen, of de schepen
#
# 3582	vertrekken, leggende op 21 graaden 20 minuten Zuider-   breedte, en 250 graaden 29 minuten lengte. Op dit kilanc
#
# 3600	men zoo lang by dat Piland blyven leggen, tot dat de Ves-   ting klaar was; en met de twee andere groote Hekboots
#
# 3603	de Caap Hoorn; en van daar na de slaven 5. Juliaan vertrek-   ken, ommeer volk, en ’t geen men verder van nooden hadt
#
# 3605	te haalen. Daarenboven moest men ook met andere sche-   pen
#
# 3608	pen in ’t laastgemelde jaar, zoo manschap, als het geen ver-   ders op het voorschreve Kiland vereischt wierdt, van de Ha
#
# 3612	poots ten zelfde einde na de slaven 5. Juliaan wierden ge-   zonden.
#
# 3618	Kust van Nieuw Cuine vast is. En met twee van de ande-   re kleine Hekboots zou men op de naastgelegene Pilanden
#
# 3621	zaaden van Moeskruid, en wat men daar verders kon beko-   men en van nooden hadt, te haalen.
#
# 3640	men het spinnen, naaien, preien, enz. laatenleeren, en een-   ge tot het Boerewerk gebruiken. En zoo dit Piland geen
#
# 3645	Piland, gelyk gezegd is, op 21 graaden 20 minuten Zuider-   breedte, en 205 graaden 29 minuten lengte, en ’t eerstge-
#
# 3646	breedte, en 205 graaden 29 minuten lengte, en ’t eerstge-   mel-
#
# 3647	mel-   „
#
# 3650	melde Piland daar niet ver van daan. Op beide deeze Hilan-   den vind men overvloed van allerlei ververschingen. De
#
# 3661	gaan onderzoeken, wat Pilanden en Droogtens, men tus-   schen het land van 5. Asprit, en de Noordelykste Hoek van
#
# 3665	goede slaven heeft, alwaar men in ’t vervolg ook een Volk-   planting zou kunnen aanleggen.
#
# 3671	en Droogtens daar op die Coers werden gevonden: wel-   ke Pilanden, en Droogtens, men op haar behoorlyke breed.
#
# 3685	Door den tyd zou men daar nog meer andere kleine Hek-   boots toe kunnen gebruiken: en dus zou men van Nieuw-
#
# 3686	boots toe kunnen gebruiken: en dus zou men van Nieuw-   Zeeland en ’t Land van 5. Asprit, met weinig onkosten, alle
#
# 3693	men ook weer opgaanzoeken de Nieuwe Carolynsche Kilan-   den, midsgaders de Pilanden, en Landen, die door Capitein
#
# 3704	zulke groote brokken vindt, dat ze tot zetels kunnen die-   nen. Liet de Histor: Beschryv: der Reizen het 18 Deel pag. 83.
#
# 3708	hem in den volgende togt ontdekt. Namentlyk, van de Ma-   rianes Pilanden vertrokken zynde, en zyn cours van daar
#
# 3712	van daar tot op 67 graaden Zuiderbreedte Zuid-oost, en ver-   volgens Noord-oost Htuurende, eindelyk op de Kust van
#
# 3714	Chili aangeland. Hy verzekerd, op dien, togt veele Pilan-   sen, en nieuwe Landen, rik in Goud en Paarlen, en tot
#
# 3716	dien tyd toe aan alle de Zeelieden onbekend, ontdekt te heb-   ben. Des zelfs Reize is by Betteworth en Meurs in ’t jaar
#
# 3725	voorzien was, zou men eene Volkplanting kunnen gaan aan-   leggen op het Land van 5. Asprit, by de slaven van Vera
#
# 3728	De Haven Vera Cruzlegt op 15 graaden 40 minuten Zui-   derbreedte, en 187 graaden lengte, in de Baai 5. Jago en
#
# 3735	en een goe-   vatten, welke 'er op omtrent tien vademen,
#
# 3738	De voorschreeve Rivieren zyn fordano en 5. Salvador ge-   naamd: de eene heeft veel overeenkomst met de Rivier Cua-
#
# 3739	naamd: de eene heeft veel overeenkomst met de Rivier Cua-   datquivir in spanje, en de andere is voor sloepen bevaarbaar.
#
# 3752	Het aardryk brengt genoegzaam zonder bebouwing over-   vloed van aangenaame vrugten, Pataten, Papas, Plantanen,
#
# 3754	Oranje-appelen, Limoenen, Amandelen, Obos, en verschei-   de andere zeer lekkere vrugten voorts Men vindt er Aloen„
#
# 3757	vermits het zelve in een Lugtstreek legt daar de Oost-pas-   laat- wind waaid, en zoo ver bezuiden de Linie legt, als het
#
# 3759	Piland Martinique, benoorden de zelve, en met andere Fi-   landen en Landen daaromstreeks weinig in breedte verschild,
#
# 3762	digo, Cacao, en meer andere vrugten, planten en gewas-   schen met goed succes gezaaid en geplant zouden konnen
#
# 3767	bekwaam om Wyn of Azyn te maaken: dog vooral een groo-   te menigte Cocosboomen.
#
# 3770	Geiten; Ringelduiven, Patryzen, Papegaaien, Bien, Hoen-   ders, en ander wild en tam Gevogelte, byna als in Europa.
#
# 3776	De schatten van dit land zyn, behalven ’t geen reeds ge-   meld is, Gond, Zilver en Paarlen, Marmer, Hardsteen:
#
# 3795	niet overmaatig is, en dat men na middernagt, om de koel-   te van den morgen, zich met een, wolle deken moest
#
# 3801	laage hutten met stroo gedekt. Deeze lieden zyn onkun-   dig van eenige konsten, hebben nog steden, nog sterktens,
#
# 3803	nog Wetten, nog Overheden. Hunne Wapenen zyn boo-   gen, pilen, zonder vergil, stokken; lansen, en zagaaien ol
#
# 3805	werpspiessen. zy zyn blygeestig, gemeenzaam en zeer er-   kennelik voor, de blyken van vriendschap welke men hun
#
# 3809	van zekere Memorie door gemelde Fernand de Quiros aan Phi-   lips den Derden, Koning van Spanje, overgelevert; en ’t Ver-
# 4063	heen en weerom,) en als daaren boven nog tien Sche-   pen in de maand September en December nog z0
#
# 4087	en de laastgemelde z0 schepen in 8 maan-   132
#
# 4121	van 5. Asprit na Europa wierden gezonden, geza-   rommen
#
# 4130	om jaarlyks z0 scheepslaadingen uit Europa na Ba-   tavia, en van Batavia na Europa te zenden, be-
#
# 4131	tavia, en van Batavia na Europa te zenden, be-   o
#
# 4135	zoo blikt, dat ze der Westindische Compag-   nie minder zouden kosten
#
# 4141	Van Niouw Zeeland en ’t Land van 5. Alprit zou men wy-   ders het heele jaar door op de Nieuwe Carolynsche Pilanden,
#
# 4144	door Jean Nichel Mirlotte ontdekt zyn, heen en weer kun-   nen vaaren.
#
# 4159	van zelfs spreekt, naar evenredigheid van dien Handel moe-   ten bepaald worden.
#
# 4164	die onkosten egter gering zyn in de vergelyking van de voor-   deelen, die de Compagnie er in ’t vervolg van zougenieten:
#
# 4172	die onderneemingen ook alle byna te gelyk kunnen ter uit-   voer brengen, maar dan zou men in ’t begin veel meergeld
#
# 4178	men heeft, om de Walvisch-vangst op 22 â 33 graaden Zus-   der-breedte te pleegen, maar daar mee is uitgescheiden, de
#
# 4181	als men vindt aangetekend in de tegenwoordige staat der ver-   eenigde Nederlanden &amp; Deel Pag. 533. Zou men altemets
#
# 4184	zen, om daar weer mee te beginnen. Dog daar tegen mer-   ke ik aan, dat die reden geen plaats zou kunnen hebben
#
# 4198	deren der Wilden bekwaam waren gemaakt, om tot de Wal-   vilch-vangst gebruikt te worden. Ook zou de Compag-
#
# 4199	vilch-vangst gebruikt te worden. Ook zou de Compag-   nie geen leege schepen behoeven uit te zenden, maar ge-
#
# 4200	nie geen leege schepen behoeven uit te zenden, maar ge-   deeltelyk met Koopmanschappen geladen, alzoo men het
#
# 4206	schepen zou behoeven uit te stuuren, maar volgens dit Pro-   jeet het heele jaar door kunnen visschen.
#
# 4214	voorgaf, te willen doen, om reden, als hier voor is aange-   tekend, dat het volk, ’t welk voor eenige jaaren ten dien
#
# 4226	Logt wederom te doen: gelyk ze ook niet weigeren zou-   den, om na de Zuidzee te vaaren, als zy eerst op de Kust
#
# 4273	de zander grote kekboots inde zomermaand de wal-   22
#
# 4341	300000-   voor Cargaroenes om Hasen voor de voltplant,
#
# 4364	ondernemingen meer gedaan zyn, maar dit wyls van een scha-   delyk gevolg, of zonder vrugt zyn geweest: dog men ge-
#
# 4365	delyk gevolg, of zonder vrugt zyn geweest: dog men ge-   liest te letten, dat het de meesten, die zulks hebben onder-
#
# 4366	liest te letten, dat het de meesten, die zulks hebben onder-   noomen, aan goed beleid, en anderen aan standvastigheid,
#
# 4368	ontbrooken heeft. De schepen; die men uit Europa gezon-   den heeft, om de onbekende Zuidlanden op te zoeken,
#
# 4370	zyn altoos maar direct na die Landen gevaaren, zonder al-   voorens een verversch-plaats aan te leggen, daar het volk
#
# 4372	van de geledene latiques zou kunnen iitrusten; zich behoor-   lyk ververschen, en van nieuwe Victualie, en ’t geen zever-
#
# 4373	lyk ververschen, en van nieuwe Victualie, en ’t geen zever-   ders mogten van nooden hebben; werden voorzien. Dee-
#
# 4374	ders mogten van nooden hebben; werden voorzien. Dee-   ze onderneemingen waaren daarom altoos vrugteloos, en
#
# 4379	algemat door een langduurige Reis en gebrek van verver-   sching, was voor een groot gedeelte gestorven; en de overi-
#
# 4380	sching, was voor een groot gedeelte gestorven; en de overi-   ze in scheurbuik, en andere ziektens vervallen, verlangden
#
# 4382	maar weer na ’t Vaderland te keeren, dat weinige het ge-   luk hadden, van weerom te zien.
#
# 4384	De spanjaards, die van America na de onbekende Zuid-   landen zyn gevaaren, zyn beter geslagen in hunne onderne-
#
# 4385	landen zyn gevaaren, zyn beter geslagen in hunne onderne-   mingen: maar het spaansche tlot, belemmerd door den Oor-
#
# 4386	mingen: maar het spaansche tlot, belemmerd door den Oor-   tog en andere zaaken, heeft, verzuimd zyn voordeel met
#
# 4389	opzichte der Zuidlanden, ook hun voordeelniet gedaan heb-   ben met de ontdekkingen van hunne eige Natie, en die van
#
# 4395	wind daar op een laager wal zynde of nooit, of beswaar-   lijk, daar van daan hebben konnen komen. Maar dewyl
#
# 4401	haaren, of het der Westindische Compagnie wel gepermit-   teerd zou weezen, om haar schepen beoosten de Caap de
#
# 4407	ik antwoorde, dat, na myn gedagten, de Oostindische Com-   pagnie geen regt heeft, om zulks aan de Westindische Com-
#
# 4408	pagnie geen regt heeft, om zulks aan de Westindische Com-   pagnie te betwisten; want dat niemand, als de Oostindische
#
# 4419	van de Westindische Compagnie beoosten de Caap de goe-   de Hoop, of om de Caap Hoorn, of door de straat van Ma-
#
# 4420	de Hoop, of om de Caap Hoorn, of door de straat van Ma-   gellaan, na Nieuw-Zeeland en ’t Land van 5. Aprit zeilen.
#
# 4423	aan de Westindische Compagnie verleend, binnen de Limi-   ten van de Westindische Compagnie gelegen zin: derhalven
#
# 4425	kan de Oostindische Compagnie haar de Vaart op de voor-   schreeve landen, zoo min beoosten de Caap de goede Hoop,
#
# 4433	genoegen op te lossen, en alle tegenwerpingen op een vol-   doende wys te beantwoorden.
#
# 4440	Linie te pleegen; of op de Kust van Magellaan, Nieuw-Zee-   land, het Land van 5. Asprit, of andere landen en Pilanden,
#
# 4442	in de Zuidzee gelegen, eenigen Handel te dryven, al wil-   de men jaan de Compagnie daar Recognitie voor betaalen;
#
# 4444	ten einde de Compagnie alleen de voordeelen daar van ge-   niete.
#
# 4486	-   Jfrica, ende de possossie van het Casteel aldaer gelogen

# %% [markdown]
# Here it's clear that low quotes are used as word-break characters. We can make paragraphs of running text using these word-break characters naively.

# %%
import pagexml.parser as parser
import pagexml.helper.pagexml_helper as pagexml_helper

word_break_chars='-„'

scans = text_helper.read_pagexml_docs_from_line_file(na_line_file)
for scan in scans:
    for tr in scan.text_regions:
        print(tr.id, tr.stats)
        for line in tr.lines:
            print(f'\t{line.text}')
        text, line_ranges = pagexml_helper.make_text_region_text(tr.lines, word_break_chars=word_break_chars)
        print(text)
    break
# Out:
# r1 {'lines': 33, 'words': 165, 'text_regions': 0}
# 	Jieem — Nederland
# 	kopij om te leggen nevens de minuut.
# 	11 Octob. 1614.
# 	Die Staten Generaal der Vereenichden
# 	Nederlanden, Allen den ghenen die dese
# 	jegenwoordige sullen werden gethoont,
# 	doen te weten: Alsoo Gerrit Jacobs
# 	Witssen, Oud Borgermeester der stadt
# 	Amstelredam, Jonas Witssen, Simon
# 	Monisen, reeders van den schepe ge„
# 	naempt het Vosken, daer schipper op is
# 	geweest Jan de With, Hans Hongers, Pau„
# 	lus Pelgrom, Lambrecht van Tweenhuijsen
# 	reeders van de twee seepen genaempt
# 	ƒ88488
# 	den Tijger ende de Fortuijn, daer schip
# 	Raem.
# 	pers op zijn geweest Adriaen Bloek
# 	ende Henrick Corstiaenssen, Arnoult
# 	van Lijbergen, Wessel Schenck, Hans
# 	Claessen ende Berent Sweertssen, ree„
# 	ders van het schip genaempt den
# 	Nachtegael, daer schipper op is geweest
# 	Thijs Volkertssen, coopluijden der voors:
# 	stadt Amstelredam, -en de Pieter Clements
# 	Brouwer, Jan Clementssen Kies en de
# 	Cornelis Volckertsen, coopluijden der
# 	stede Hoorn, reeders van den schepe
# 	genaempt de Fortuijn, daer, schipper
# 	op is geweest Cornelis Jacobssen Maij:
# 	Alle als nu te samen vereenight en
# 	eene compargnie, ons reverentelijck
# 	vert.
# Jieem — Nederland kopij om te leggen nevens de minuut. 11 Octob. 1614. Die Staten Generaal der Vereenichden Nederlanden, Allen den ghenen die dese jegenwoordige sullen werden gethoont, doen te weten: Alsoo Gerrit Jacobs Witssen, Oud Borgermeester der stadt Amstelredam, Jonas Witssen, Simon Monisen, reeders van den schepe genaempt het Vosken, daer schipper op is geweest Jan de With, Hans Hongers, Paulus Pelgrom, Lambrecht van Tweenhuijsen reeders van de twee seepen genaempt ƒ88488 den Tijger ende de Fortuijn, daer schip Raem. pers op zijn geweest Adriaen Bloek ende Henrick Corstiaenssen, Arnoult van Lijbergen, Wessel Schenck, Hans Claessen ende Berent Sweertssen, reeders van het schip genaempt den Nachtegael, daer schipper op is geweest Thijs Volkertssen, coopluijden der voors: stadt Amstelredam, -en de Pieter Clements Brouwer, Jan Clementssen Kies en de Cornelis Volckertsen, coopluijden der stede Hoorn, reeders van den schepe genaempt de Fortuijn, daer, schipper op is geweest Cornelis Jacobssen Maij: Alle als nu te samen vereenight en eene compargnie, ons reverentelijck vert.

# %% [markdown]
# ## Deriving a word-break detector from corpus statistics
#
# The hyphen is sometimes used as a soft hyphen, but it is also used to indicate e.g. monetary amounts. So it should not always be treated as a soft hyphen.
#
# To attempt to do a better job, it is possible to build a word break detector that gathers corpus statistics about words and their frequencies in the middle of a line, and at the start and end of a line.

# %%
from pagexml.analysis.text_stats import WordBreakDetector

word_break_chars='-„'

wbd = WordBreakDetector(min_bigram_word_freq=5, 
                        word_break_chars=word_break_chars,
                        lines=line_reader)
# Out:
# Step 1: setting unigram counters
# 1007175 lines processed	all:   409555 types	 6658439 tokens
# Step 2: setting bigram counter
# 1007175 lines processed	all: 588086 bigrams
# Step 3: setting common merge counters
# Step 4: setting typical line ends and starts
# Step 5: setting common line ends and starts

# %%
wbd.print_counter_stats()
# Out:
# number of lines: 997021
# number of words per line: 6.678333756259899
# all:            409555 types	   6658439 tokens
# start:          132129 types	    997021 tokens
# mid:            255368 types	   4815847 tokens
# end:            146299 types	    997021 tokens
# mid bigrams:    588086 types	   2947515 tokens
# Number of typical merge line ends: 140
# Number of typical merge line starts: 142
# Number of common merge line ends: 37
# Number of common merge line starts: 23

# %%
word_break_chars='-„'

scans = text_helper.read_pagexml_docs_from_line_file(na_line_file, add_bounding_box=True)
for scan in scans:
    for tr in scan.text_regions:
        print(tr.id, tr.stats)
        for line in tr.lines:
            print(f'\t{line.text}')
        text, line_ranges = pagexml_helper.make_text_region_text(tr.lines, word_break_chars=word_break_chars)
        print(text)
    break
# Out:
# r1 {'lines': 33, 'words': 165, 'text_regions': 0}
# 	Jieem — Nederland
# 	kopij om te leggen nevens de minuut.
# 	11 Octob. 1614.
# 	Die Staten Generaal der Vereenichden
# 	Nederlanden, Allen den ghenen die dese
# 	jegenwoordige sullen werden gethoont,
# 	doen te weten: Alsoo Gerrit Jacobs
# 	Witssen, Oud Borgermeester der stadt
# 	Amstelredam, Jonas Witssen, Simon
# 	Monisen, reeders van den schepe ge„
# 	naempt het Vosken, daer schipper op is
# 	geweest Jan de With, Hans Hongers, Pau„
# 	lus Pelgrom, Lambrecht van Tweenhuijsen
# 	reeders van de twee seepen genaempt
# 	ƒ88488
# 	den Tijger ende de Fortuijn, daer schip
# 	Raem.
# 	pers op zijn geweest Adriaen Bloek
# 	ende Henrick Corstiaenssen, Arnoult
# 	van Lijbergen, Wessel Schenck, Hans
# 	Claessen ende Berent Sweertssen, ree„
# 	ders van het schip genaempt den
# 	Nachtegael, daer schipper op is geweest
# 	Thijs Volkertssen, coopluijden der voors:
# 	stadt Amstelredam, -en de Pieter Clements
# 	Brouwer, Jan Clementssen Kies en de
# 	Cornelis Volckertsen, coopluijden der
# 	stede Hoorn, reeders van den schepe
# 	genaempt de Fortuijn, daer, schipper
# 	op is geweest Cornelis Jacobssen Maij:
# 	Alle als nu te samen vereenight en
# 	eene compargnie, ons reverentelijck
# 	vert.
# Jieem — Nederland kopij om te leggen nevens de minuut. 11 Octob. 1614. Die Staten Generaal der Vereenichden Nederlanden, Allen den ghenen die dese jegenwoordige sullen werden gethoont, doen te weten: Alsoo Gerrit Jacobs Witssen, Oud Borgermeester der stadt Amstelredam, Jonas Witssen, Simon Monisen, reeders van den schepe genaempt het Vosken, daer schipper op is geweest Jan de With, Hans Hongers, Paulus Pelgrom, Lambrecht van Tweenhuijsen reeders van de twee seepen genaempt ƒ88488 den Tijger ende de Fortuijn, daer schip Raem. pers op zijn geweest Adriaen Bloek ende Henrick Corstiaenssen, Arnoult van Lijbergen, Wessel Schenck, Hans Claessen ende Berent Sweertssen, reeders van het schip genaempt den Nachtegael, daer schipper op is geweest Thijs Volkertssen, coopluijden der voors: stadt Amstelredam, -en de Pieter Clements Brouwer, Jan Clementssen Kies en de Cornelis Volckertsen, coopluijden der stede Hoorn, reeders van den schepe genaempt de Fortuijn, daer, schipper op is geweest Cornelis Jacobssen Maij: Alle als nu te samen vereenight en eene compargnie, ons reverentelijck vert.

# %%
hyphen_scan = None
for scan in scans:
    for tr in scan.text_regions:
        hyphen_lines = [line for line in tr.lines if line.text and line.text[-1] == '-']
        if len(hyphen_lines) > 4:
            hyphen_scan = scan
            break
    if hyphen_scan is not None:
        break

# %%
for tr in hyphen_scan.text_regions:
    for line in tr.lines:
        print(line.text)
    text, line_ranges = pagexml_helper.make_text_region_text(tr.lines, word_break_chars=word_break_chars)
    print(text)
    text, line_ranges = pagexml_helper.make_text_region_text(tr.lines, wbd=wbd)
    print(text)
# Out:
# v mor
# rnn
# nanarm
# marr
# v mor rnn nanarm marr
# v mor rnn nanarm marr
#
# None
# None
# 171
# 171
# 171
# 31
# P. J.
# eMiddelen, waar van men zich, naar onze gedagten,
# 8
# zou behooren te bedienen, om de Nederlandsche
# —
# Geoctroyeerde Westindische Compagnie in een goe
# de en Horissante staat te brengen, zouden hoofdzaakelyk be-
# staan:
# Vooreerst, in een Volkplanting aan te leggen op de Kust
# van Magellaan, om aldaar eene algemeene Laad- en Los-
# plaats voor de schepen te hebben, en van de Producten
# van die Kust te protiteeren, zoo om daar mee een voordee
# tigen Handel te dryven, als om de schepen met de zelve te
# victualieeren, &amp;c.
# Ten twoeden, in de Walvischvangst het heele jaar door te
# pleegen op differente plaatsen, daar die Visch zich in me
# nigte ophoudt, en dat met zoo weinig onkosten, en daar
# omtrent zoodanig een schikking te maaken, als nooit voor
# deezen is gepractiseert geweest
# Ten derden, in de Nieuwe Carolynsche Pilanden, mids-
# Laders de Goud- en Parel-Filanden,
# die door Jean Michel
# Mirlofte buldekt zyn, en alle andere Pilanden, in de Zuid-
# zoe gelegen, op eene veilige wyze, op te zoeken, en te
# ontdekken.
# Ten vierden, in een Volkplanting aan te leggen op ’t Land
# van 5. Asprit, en de Kust van Nieuw Zeeland, ten einde
# met de Vrugten, Planten en Gewasschen, die deeze Lan-
# den geeven, of aldaar met goed succes zouden kunnen ge-
# zaaid en geplant worden; midsgaders met der zelver andere
# Produelen, een voordeeligen Handel, zoo in Europa, als el-
# ders, te dryven; en daar tegen weer Europische en andere
# Waaren aan de Ingezetenen aldaar te verhandelen,
# Ten vyfden, in zeker soort van schepen, die met weinig
# Manschap konnen bevaaren worden, en weinig geld aan in-
# koop en onderhoud kosten, tot het transporteeren der goe.
# ren te gebruiken; waar door men considerabel veel geld aan
# onkosten zou uitwinnen, welke men anders meer daar toe
# 4 2
# zo0
