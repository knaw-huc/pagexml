# %% [markdown]
# # Reading and analysing archives with many PageXML files
#
# This tutorial demonstrates how to read larger sets of [PageXML](https://www.primaresearch.org/tools/PAGELibraries) files that are combined in zip or tar archives.
#
# As an example of a zipped archive, this tutorial uses one of datasets provided by the [National Archives of the Netherlands](https://www.nationaalarchief.nl/en) (NA) via their HTR repository on [Zenodo](https://zenodo.org/): https://zenodo.org/record/6414086#.Y8Elk-zMIUo. The repository contains many other HTR PageXML datasets that NA made available.
#
# The datasets contains HTR output in [PageXML](https://www.primaresearch.org/tools/PAGELibraries) format of scans from the following archive:
# - _Notaris mr. D.A.M.de Fremery te Assen, 1899-1915, 114.11, 1_ ([EAD](https://www.drentsarchief.nl/onderzoeken/archiefstukken?mivast=34&mizig=210&miadt=34&micode=0114.11&miview=inv2)). This is an archive maintained by the [Drents Archief](https://www.drentsarchief.nl).
# - _Verspreide West-Indische stukken, 1614-1875, 1.05.06, 1-1413_ ([EAD](https://www.nationaalarchief.nl/onderzoeken/archief/1.05.06/invnr/%401?query=1.05.06&search-type=inventory)). This is an archive maintained by the [Nationaal Archief](https://www.nationaalarchief.nl/en).
#
# You can download the datasets via the following URLs:
# - https://zenodo.org/record/6414086/files/HTR%20results%20DA%200114.11%20PAGE.zip?download=1
# - https://zenodo.org/record/6414086/files/HTR%20results%201.05.06%20PAGE.zip?download=1

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Extracting PageXML files from Zip/Tar files
#
# The example zip files contains of smaller zip files, that each have a number of PageXML files.

# %%
from pagexml.helper.file_helper import read_page_archive_files

da_archive_file = '../data/HTR results DA 0114.11 PAGE.zip'
na_archive_file = '../data/HTR results 1.05.06 PAGE.zip'

read_page_archive_files(da_archive_file)
# Out:
# <generator object read_page_archive_files at 0x11236c740>

# %%
page_fileinfo, page_data = next(read_page_archive_files(da_archive_file))

# file information of the first PageXML file in the zip file
page_fileinfo
# Out:
# {'source_file': ['../data/HTR results DA 0114.11 PAGE.zip', '1.zip'],
#  'archived_filename': 'NL-AsnDA_0114.11_1_0001.xml',
#  'archived_filepath': 'NL-AsnDA_0114.11_1_0001.xml'}

# %% [markdown]
# The fileinfo contains three fields:
#
# 1. `source_file`: The name of the zip/tar archive file that the PageXML file was extracted from. If the archive file consists of zip/tar archvie files, this property will be a list of the hierarchy of zip/tar files that the PageXML file was extracted from.
# 2. `archived_filename`: the name of the PageXML file
# 3. `archived_filepath`: the full path of the PageXML in the zip/tar archive.

# %% [markdown]
# The file data contains the PageXML content in byte string:

# %%
# the content of the first PageXML file in the zip file
page_data[:1000]
# Out:
# b'<PcGts xmlns="http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15 http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15/pagecontent.xsd">\n  <Metadata>\n    <Creator>prov=READ-COOP:name=PyLaia@Transkribus:model_id=21087:version=0.0.1\nprov=University of Rostock/Institute of Mathematics/CITlab|PLANET AI GmbH/Tobias Gruening/tobias.gruening@planet-ai.de:name=de.uros.citlab.module.baseline2polygon.B2PSeamMultiOriented:v=2.6.6\nprov=University of Rostock/Institute of Mathematics/CITlab|PLANET AI GmbH/Tobias Gruening/tobias.gruening@planet-ai.de:name=/net_tf/LA73_249_0mod360.pb:de.uros.citlab.segmentation.CITlab_LA_ML:v=2.6.6\nTranskribus\n</Creator>\n    <Created>2020-09-16T15:29:40.548+02:00</Created>\n    <LastChange>2020-09-16T15:29:51.557+02:00</LastChange>\n  </Metadata>\n  <Page imageFilename="NL-AsnDA_0114.11_1_0001.jpg" imageWidth="2'

# %%
from pagexml.parser import parse_pagexml_file

scan = parse_pagexml_file(pagexml_file=page_fileinfo['archived_filename'], pagexml_data=page_data)
scan
# Out:
# PageXMLScan(
# 	id=NL-AsnDA_0114.11_1_0001.jpg,
# 	type=['pagexml_doc', 'text_region', 'scan'],
# 	stats={"lines": 49, "words": 306, "text_regions": 3, "columns": 0, "extra": 0, "pages": 0}
# )

# %% [markdown]
# The West-Indische Stukken archive

# %%
page_fileinfo, page_data = next(read_page_archive_files(na_archive_file))
page_fileinfo
# Out:
# {'source_file': ['../data/HTR results 1.05.06 PAGE.zip', '1.zip'],
#  'archived_filename': 'NL-HaNA_1.05.06_1_0001.xml',
#  'archived_filepath': 'NL-HaNA_1.05.06_1_0001.xml'}

# %%
scan = parse_pagexml_file(pagexml_file=page_fileinfo['archived_filename'], pagexml_data=page_data)

scan
# Out:
# PageXMLScan(
# 	id=NL-HaNA_1.05.06_1_0001.jpg,
# 	type=['pagexml_doc', 'text_region', 'scan'],
# 	stats={"lines": 33, "words": 165, "text_regions": 1, "columns": 0, "extra": 0, "pages": 0}
# )

# %%
scan.stats
# Out:
# {'lines': 33,
#  'words': 165,
#  'text_regions': 1,
#  'columns': 0,
#  'extra': 0,
#  'pages': 0}

# %% [markdown]
# The static `.stats` function returns a dictionary with a count of the number of text regions, lines and words (elements that are part of the PageXML specification), as well as the three elements `pages`, `columns` and `extra`. The latter three are sub-classes of PageXMLTextRegion that are not part of the PageXML spec but are part of the physical structure domain.
#
# Often scan images represent an opening of a book, consisting of two physical pages (odd and even numbered, left and right, ...). If you know where the page split is, you can split the scan and create two PageXMLPage documents. Pages can have `PageXMLColumn`s as well as extra `PageXMLTextRegion`s such as headers, footers and marginalia.

# %%
from pagexml.helper.pagexml_helper import pretty_print_textregion

pretty_print_textregion(scan)
# Out:
#          Jieem — Nederland
#  kopij om te leggen nevens de minuut.
#
# 11 Octob. 1614.
#
#                Die Staten Generaal der Vereenichden
#
#            Nederlanden, Allen den ghenen die dese
#            jegenwoordige sullen werden gethoont,
#           doen te weten: Alsoo Gerrit Jacobs
#            Witssen, Oud Borgermeester der stadt
#            Amstelredam, Jonas Witssen, Simon
#            Monisen, reeders van den schepe ge„
#           naempt het Vosken, daer schipper op is
#           geweest Jan de With, Hans Hongers, Pau„
#           lus Pelgrom, Lambrecht van Tweenhuijsen
#           reeders van de twee seepen genaempt
#   ƒ88488   den Tijger ende de Fortuijn, daer schip
#  Raem.
#            pers op zijn geweest Adriaen Bloek
#           ende Henrick Corstiaenssen, Arnoult
#           van Lijbergen, Wessel Schenck, Hans
#           Claessen ende Berent Sweertssen, ree„
#           ders van het schip genaempt den
#           Nachtegael, daer schipper op is geweest
#           Thijs Volkertssen, coopluijden der voors:
#           stadt Amstelredam, -en de Pieter Clements
#           Brouwer, Jan Clementssen Kies en de
#           Cornelis Volckertsen, coopluijden der
#           stede Hoorn, reeders van den schepe
#           genaempt de Fortuijn, daer, schipper
#          op is geweest Cornelis Jacobssen Maij:
#           Alle als nu te samen vereenight en
#           eene compargnie, ons reverentelijck
#                                            vert.

# %% [markdown]
# ## Examing the structure of each archive file
#
# In these example datasets, the zip file contains one or more sub-archives of HTR data, each sub-archive contained in a smaller zip file. From the hierarchy of `source_file`s, it is possible to group the PageXML files per sub-archive.
#
# Because the PageXML objects can be big and archives can contain tens or hundreds of thousands of PageXML files, extracting them all can therefore take a significant amount of time, it can be handy to first get an overview of the structure of these zip files and see how many scans there are.
#
# You can pass `filenames_only=True` to the `read_page_archive_files` function to extract only the filenames.

# %%
from collections import defaultdict

scans = defaultdict(lambda: defaultdict(set))

archives = [
    {'id': 'NL-AsnDA_0114.11', 'file': '../data/HTR results DA 0114.11 PAGE.zip'},
    {'id': 'NL-HaNA_1.05.06', 'file': '../data/HTR results 1.05.06 PAGE.zip'}    
]

# %%
for archive in archives:
    for page_fileinfo, _ in read_page_archive_files(archive['file'], 
                                                            filenames_only=True,
                                                            show_progress=True):
        volume = f"{archive['id']}_{page_fileinfo['source_file'][-1].replace('.zip', '')}"
        scans[archive['id']][volume].add(page_fileinfo['archived_filename'])
# Out:
# extracting PageXML files from ../data/HTR results DA 0114.11 PAGE.zip: 630it [00:00, 2832.57it/s]
# extracting PageXML files from ../data/HTR results 1.05.06 PAGE.zip: 15857it [00:03, 4085.46it/s]

# %%
for archive_id in scans:
    print(f'\narchive {archive_id}')
    for volume in scans[archive_id]:
        print(f'\tvolume: {volume}\tnumber of scans: {len(scans[archive_id][volume])}')
# Out:
# archive NL-AsnDA_0114.11
# 	volume: NL-AsnDA_0114.11_1	number of scans: 630
#
# archive NL-HaNA_1.05.06
# 	volume: NL-HaNA_1.05.06_1	number of scans: 5
# 	volume: NL-HaNA_1.05.06_10	number of scans: 53
# 	volume: NL-HaNA_1.05.06_100	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1005	number of scans: 18
# 	volume: NL-HaNA_1.05.06_1007	number of scans: 7
# 	volume: NL-HaNA_1.05.06_101	number of scans: 5
# 	volume: NL-HaNA_1.05.06_102	number of scans: 39
# 	volume: NL-HaNA_1.05.06_103	number of scans: 4
# 	volume: NL-HaNA_1.05.06_1038	number of scans: 45
# 	volume: NL-HaNA_1.05.06_1039	number of scans: 55
# 	volume: NL-HaNA_1.05.06_104	number of scans: 158
# 	volume: NL-HaNA_1.05.06_105	number of scans: 17
# 	volume: NL-HaNA_1.05.06_1050	number of scans: 8
# 	volume: NL-HaNA_1.05.06_1051	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1053	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1055	number of scans: 3
# 	volume: NL-HaNA_1.05.06_106	number of scans: 24
# 	volume: NL-HaNA_1.05.06_107	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1076	number of scans: 8
# 	volume: NL-HaNA_1.05.06_1077	number of scans: 21
# 	volume: NL-HaNA_1.05.06_1078	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1079	number of scans: 3
# 	volume: NL-HaNA_1.05.06_108	number of scans: 11
# 	volume: NL-HaNA_1.05.06_1080	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1081	number of scans: 15
# 	volume: NL-HaNA_1.05.06_1082	number of scans: 7
# 	volume: NL-HaNA_1.05.06_1083	number of scans: 4
# 	volume: NL-HaNA_1.05.06_1084	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1086	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1087	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1088	number of scans: 2
# 	volume: NL-HaNA_1.05.06_1089	number of scans: 3
# 	volume: NL-HaNA_1.05.06_108A	number of scans: 3
# 	volume: NL-HaNA_1.05.06_109	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1092	number of scans: 7
# 	volume: NL-HaNA_1.05.06_1093	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1096	number of scans: 3
# 	volume: NL-HaNA_1.05.06_11	number of scans: 9
# 	volume: NL-HaNA_1.05.06_110	number of scans: 7
# 	volume: NL-HaNA_1.05.06_1103	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1104	number of scans: 3
# 	volume: NL-HaNA_1.05.06_111	number of scans: 23
# 	volume: NL-HaNA_1.05.06_1111	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1113	number of scans: 7
# 	volume: NL-HaNA_1.05.06_1118	number of scans: 7
# 	volume: NL-HaNA_1.05.06_112	number of scans: 46
# 	volume: NL-HaNA_1.05.06_113	number of scans: 5
# 	volume: NL-HaNA_1.05.06_114	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1145	number of scans: 28
# 	volume: NL-HaNA_1.05.06_1146	number of scans: 8
# 	volume: NL-HaNA_1.05.06_1148	number of scans: 2
# 	volume: NL-HaNA_1.05.06_115	number of scans: 42
# 	volume: NL-HaNA_1.05.06_1151	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1153	number of scans: 19
# 	volume: NL-HaNA_1.05.06_1154	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1155	number of scans: 120
# 	volume: NL-HaNA_1.05.06_1157	number of scans: 29
# 	volume: NL-HaNA_1.05.06_1159	number of scans: 24
# 	volume: NL-HaNA_1.05.06_116	number of scans: 10
# 	volume: NL-HaNA_1.05.06_1163	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1165A	number of scans: 21
# 	volume: NL-HaNA_1.05.06_1166	number of scans: 407
# 	volume: NL-HaNA_1.05.06_1167	number of scans: 583
# 	volume: NL-HaNA_1.05.06_1168	number of scans: 33
# 	volume: NL-HaNA_1.05.06_1168A	number of scans: 39
# 	volume: NL-HaNA_1.05.06_1169	number of scans: 47
# 	volume: NL-HaNA_1.05.06_117	number of scans: 49
# 	volume: NL-HaNA_1.05.06_1170	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1171	number of scans: 338
# 	volume: NL-HaNA_1.05.06_1172	number of scans: 225
# 	volume: NL-HaNA_1.05.06_1173	number of scans: 243
# 	volume: NL-HaNA_1.05.06_1174	number of scans: 222
# 	volume: NL-HaNA_1.05.06_1177	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1178	number of scans: 3
# 	volume: NL-HaNA_1.05.06_118	number of scans: 10
# 	volume: NL-HaNA_1.05.06_1182	number of scans: 448
# 	volume: NL-HaNA_1.05.06_1183	number of scans: 266
# 	volume: NL-HaNA_1.05.06_1184	number of scans: 201
# 	volume: NL-HaNA_1.05.06_1189	number of scans: 3
# 	volume: NL-HaNA_1.05.06_119	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1190	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1191	number of scans: 246
# 	volume: NL-HaNA_1.05.06_1192	number of scans: 33
# 	volume: NL-HaNA_1.05.06_1193	number of scans: 15
# 	volume: NL-HaNA_1.05.06_1195	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1196	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1197	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1197A	number of scans: 35
# 	volume: NL-HaNA_1.05.06_1198	number of scans: 7
# 	volume: NL-HaNA_1.05.06_1199	number of scans: 11
# 	volume: NL-HaNA_1.05.06_12	number of scans: 9
# 	volume: NL-HaNA_1.05.06_120	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1200	number of scans: 8
# 	volume: NL-HaNA_1.05.06_1201	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1202	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1203	number of scans: 67
# 	volume: NL-HaNA_1.05.06_1205	number of scans: 248
# 	volume: NL-HaNA_1.05.06_1206	number of scans: 11
# 	volume: NL-HaNA_1.05.06_1207	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1208	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1209	number of scans: 6
# 	volume: NL-HaNA_1.05.06_121	number of scans: 25
# 	volume: NL-HaNA_1.05.06_1210	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1211	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1212	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1213	number of scans: 11
# 	volume: NL-HaNA_1.05.06_1214	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1215	number of scans: 7
# 	volume: NL-HaNA_1.05.06_1216	number of scans: 17
# 	volume: NL-HaNA_1.05.06_1217	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1218	number of scans: 148
# 	volume: NL-HaNA_1.05.06_1219	number of scans: 25
# 	volume: NL-HaNA_1.05.06_122	number of scans: 10
# 	volume: NL-HaNA_1.05.06_1220	number of scans: 109
# 	volume: NL-HaNA_1.05.06_1221	number of scans: 99
# 	volume: NL-HaNA_1.05.06_1222	number of scans: 71
# 	volume: NL-HaNA_1.05.06_1223	number of scans: 49
# 	volume: NL-HaNA_1.05.06_1224	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1225	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1226	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1227	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1228	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1229	number of scans: 7
# 	volume: NL-HaNA_1.05.06_123	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1230	number of scans: 2
# 	volume: NL-HaNA_1.05.06_1231	number of scans: 2
# 	volume: NL-HaNA_1.05.06_1232	number of scans: 2
# 	volume: NL-HaNA_1.05.06_1233	number of scans: 27
# 	volume: NL-HaNA_1.05.06_1234	number of scans: 21
# 	volume: NL-HaNA_1.05.06_1235	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1236	number of scans: 31
# 	volume: NL-HaNA_1.05.06_1237	number of scans: 16
# 	volume: NL-HaNA_1.05.06_1238	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1239	number of scans: 5
# 	volume: NL-HaNA_1.05.06_124	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1240	number of scans: 17
# 	volume: NL-HaNA_1.05.06_1241	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1242	number of scans: 11
# 	volume: NL-HaNA_1.05.06_1243	number of scans: 15
# 	volume: NL-HaNA_1.05.06_1244	number of scans: 6
# 	volume: NL-HaNA_1.05.06_1245	number of scans: 18
# 	volume: NL-HaNA_1.05.06_1246	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1247	number of scans: 20
# 	volume: NL-HaNA_1.05.06_1248	number of scans: 11
# 	volume: NL-HaNA_1.05.06_125	number of scans: 37
# 	volume: NL-HaNA_1.05.06_1254	number of scans: 2
# 	volume: NL-HaNA_1.05.06_126	number of scans: 16
# 	volume: NL-HaNA_1.05.06_127	number of scans: 121
# 	volume: NL-HaNA_1.05.06_128	number of scans: 7
# 	volume: NL-HaNA_1.05.06_129	number of scans: 2
# 	volume: NL-HaNA_1.05.06_13	number of scans: 80
# 	volume: NL-HaNA_1.05.06_130	number of scans: 7
# 	volume: NL-HaNA_1.05.06_132	number of scans: 7
# 	volume: NL-HaNA_1.05.06_1328	number of scans: 57
# 	volume: NL-HaNA_1.05.06_1329	number of scans: 56
# 	volume: NL-HaNA_1.05.06_133	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1333	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1335	number of scans: 5
# 	volume: NL-HaNA_1.05.06_134	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1342	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1343	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1344	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1345	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1346	number of scans: 6
# 	volume: NL-HaNA_1.05.06_1347	number of scans: 22
# 	volume: NL-HaNA_1.05.06_135	number of scans: 45
# 	volume: NL-HaNA_1.05.06_1354	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1359	number of scans: 2
# 	volume: NL-HaNA_1.05.06_136	number of scans: 11
# 	volume: NL-HaNA_1.05.06_1360	number of scans: 2
# 	volume: NL-HaNA_1.05.06_1360A	number of scans: 2
# 	volume: NL-HaNA_1.05.06_1361	number of scans: 17
# 	volume: NL-HaNA_1.05.06_1364	number of scans: 4
# 	volume: NL-HaNA_1.05.06_1365	number of scans: 2
# 	volume: NL-HaNA_1.05.06_1366	number of scans: 2
# 	volume: NL-HaNA_1.05.06_1367	number of scans: 2
# 	volume: NL-HaNA_1.05.06_137	number of scans: 9
# 	volume: NL-HaNA_1.05.06_1370	number of scans: 2
# 	volume: NL-HaNA_1.05.06_1371	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1377	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1378	number of scans: 3
# 	volume: NL-HaNA_1.05.06_138	number of scans: 14
# 	volume: NL-HaNA_1.05.06_1382	number of scans: 2
# 	volume: NL-HaNA_1.05.06_1383	number of scans: 29
# 	volume: NL-HaNA_1.05.06_1386	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1388	number of scans: 2
# 	volume: NL-HaNA_1.05.06_139	number of scans: 11
# 	volume: NL-HaNA_1.05.06_1391	number of scans: 8
# 	volume: NL-HaNA_1.05.06_1393	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1394	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1395	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1396	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1397	number of scans: 3
# 	volume: NL-HaNA_1.05.06_140	number of scans: 4
# 	volume: NL-HaNA_1.05.06_1401	number of scans: 3
# 	volume: NL-HaNA_1.05.06_1402	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1403	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1406	number of scans: 15
# 	volume: NL-HaNA_1.05.06_1406A	number of scans: 5
# 	volume: NL-HaNA_1.05.06_1408	number of scans: 15
# 	volume: NL-HaNA_1.05.06_1409	number of scans: 3
# 	volume: NL-HaNA_1.05.06_141	number of scans: 11
# 	volume: NL-HaNA_1.05.06_1410	number of scans: 4
# 	volume: NL-HaNA_1.05.06_1411	number of scans: 85
# 	volume: NL-HaNA_1.05.06_1412	number of scans: 10
# 	volume: NL-HaNA_1.05.06_1413	number of scans: 11
# 	volume: NL-HaNA_1.05.06_142	number of scans: 3
# 	volume: NL-HaNA_1.05.06_143	number of scans: 22
# 	volume: NL-HaNA_1.05.06_144	number of scans: 13
# 	volume: NL-HaNA_1.05.06_146	number of scans: 3
# 	volume: NL-HaNA_1.05.06_147	number of scans: 75
# 	volume: NL-HaNA_1.05.06_148	number of scans: 13
# 	volume: NL-HaNA_1.05.06_149	number of scans: 81
# 	volume: NL-HaNA_1.05.06_150	number of scans: 28
# 	volume: NL-HaNA_1.05.06_151	number of scans: 7
# 	volume: NL-HaNA_1.05.06_152	number of scans: 13
# 	volume: NL-HaNA_1.05.06_153	number of scans: 9
# 	volume: NL-HaNA_1.05.06_154	number of scans: 6
# 	volume: NL-HaNA_1.05.06_155	number of scans: 5
# 	volume: NL-HaNA_1.05.06_156	number of scans: 7
# 	volume: NL-HaNA_1.05.06_157	number of scans: 11
# 	volume: NL-HaNA_1.05.06_158	number of scans: 5
# 	volume: NL-HaNA_1.05.06_159	number of scans: 15
# 	volume: NL-HaNA_1.05.06_160	number of scans: 3
# 	volume: NL-HaNA_1.05.06_161	number of scans: 5
# 	volume: NL-HaNA_1.05.06_164	number of scans: 19
# 	volume: NL-HaNA_1.05.06_169	number of scans: 12
# 	volume: NL-HaNA_1.05.06_171	number of scans: 12
# 	volume: NL-HaNA_1.05.06_172	number of scans: 3
# 	volume: NL-HaNA_1.05.06_173	number of scans: 3
# 	volume: NL-HaNA_1.05.06_173A	number of scans: 8
# 	volume: NL-HaNA_1.05.06_174	number of scans: 4
# 	volume: NL-HaNA_1.05.06_175	number of scans: 4
# 	volume: NL-HaNA_1.05.06_176	number of scans: 4
# 	volume: NL-HaNA_1.05.06_177	number of scans: 5
# 	volume: NL-HaNA_1.05.06_177A	number of scans: 5
# 	volume: NL-HaNA_1.05.06_184	number of scans: 7
# 	volume: NL-HaNA_1.05.06_185	number of scans: 57
# 	volume: NL-HaNA_1.05.06_186	number of scans: 19
# 	volume: NL-HaNA_1.05.06_187	number of scans: 3
# 	volume: NL-HaNA_1.05.06_2	number of scans: 17
# 	volume: NL-HaNA_1.05.06_21	number of scans: 11
# 	volume: NL-HaNA_1.05.06_213	number of scans: 54
# 	volume: NL-HaNA_1.05.06_214	number of scans: 5
# 	volume: NL-HaNA_1.05.06_215	number of scans: 7
# 	volume: NL-HaNA_1.05.06_216	number of scans: 9
# 	volume: NL-HaNA_1.05.06_217	number of scans: 8
# 	volume: NL-HaNA_1.05.06_218	number of scans: 11
# 	volume: NL-HaNA_1.05.06_219	number of scans: 11
# 	volume: NL-HaNA_1.05.06_22	number of scans: 17
# 	volume: NL-HaNA_1.05.06_220	number of scans: 9
# 	volume: NL-HaNA_1.05.06_226A	number of scans: 191
# 	volume: NL-HaNA_1.05.06_23	number of scans: 7
# 	volume: NL-HaNA_1.05.06_231	number of scans: 19
# 	volume: NL-HaNA_1.05.06_233	number of scans: 11
# 	volume: NL-HaNA_1.05.06_236	number of scans: 7
# 	volume: NL-HaNA_1.05.06_24	number of scans: 7
# 	volume: NL-HaNA_1.05.06_246	number of scans: 3
# 	volume: NL-HaNA_1.05.06_246A	number of scans: 7
# 	volume: NL-HaNA_1.05.06_247	number of scans: 26
# 	volume: NL-HaNA_1.05.06_248	number of scans: 3
# 	volume: NL-HaNA_1.05.06_249	number of scans: 5
# 	volume: NL-HaNA_1.05.06_25	number of scans: 24
# 	volume: NL-HaNA_1.05.06_259	number of scans: 3
# 	volume: NL-HaNA_1.05.06_26	number of scans: 13
# 	volume: NL-HaNA_1.05.06_260	number of scans: 8
# 	volume: NL-HaNA_1.05.06_261	number of scans: 7
# 	volume: NL-HaNA_1.05.06_262	number of scans: 3
# 	volume: NL-HaNA_1.05.06_263	number of scans: 2
# 	volume: NL-HaNA_1.05.06_264	number of scans: 15
# 	volume: NL-HaNA_1.05.06_265	number of scans: 3
# 	volume: NL-HaNA_1.05.06_266	number of scans: 5
# 	volume: NL-HaNA_1.05.06_268	number of scans: 4
# 	volume: NL-HaNA_1.05.06_269	number of scans: 2
# 	volume: NL-HaNA_1.05.06_27	number of scans: 7
# 	volume: NL-HaNA_1.05.06_270	number of scans: 10
# 	volume: NL-HaNA_1.05.06_271	number of scans: 3
# 	volume: NL-HaNA_1.05.06_272	number of scans: 4
# 	volume: NL-HaNA_1.05.06_273	number of scans: 3
# 	volume: NL-HaNA_1.05.06_275	number of scans: 7
# 	volume: NL-HaNA_1.05.06_278	number of scans: 10
# 	volume: NL-HaNA_1.05.06_279	number of scans: 7
# 	volume: NL-HaNA_1.05.06_287	number of scans: 67
# 	volume: NL-HaNA_1.05.06_292	number of scans: 57
# 	volume: NL-HaNA_1.05.06_3	number of scans: 6
# 	volume: NL-HaNA_1.05.06_304	number of scans: 35
# 	volume: NL-HaNA_1.05.06_305	number of scans: 3
# 	volume: NL-HaNA_1.05.06_306	number of scans: 5
# 	volume: NL-HaNA_1.05.06_307	number of scans: 210
# 	volume: NL-HaNA_1.05.06_314	number of scans: 5
# 	volume: NL-HaNA_1.05.06_315	number of scans: 3
# 	volume: NL-HaNA_1.05.06_318	number of scans: 13
# 	volume: NL-HaNA_1.05.06_325	number of scans: 11
# 	volume: NL-HaNA_1.05.06_326	number of scans: 9
# 	volume: NL-HaNA_1.05.06_327	number of scans: 34
# 	volume: NL-HaNA_1.05.06_328	number of scans: 17
# 	volume: NL-HaNA_1.05.06_329	number of scans: 3
# 	volume: NL-HaNA_1.05.06_330	number of scans: 8
# 	volume: NL-HaNA_1.05.06_333	number of scans: 3
# 	volume: NL-HaNA_1.05.06_334	number of scans: 5
# 	volume: NL-HaNA_1.05.06_339	number of scans: 3
# 	volume: NL-HaNA_1.05.06_343	number of scans: 9
# 	volume: NL-HaNA_1.05.06_344	number of scans: 19
# 	volume: NL-HaNA_1.05.06_353	number of scans: 9
# 	volume: NL-HaNA_1.05.06_35A	number of scans: 45
# 	volume: NL-HaNA_1.05.06_36	number of scans: 8
# 	volume: NL-HaNA_1.05.06_37	number of scans: 3
# 	volume: NL-HaNA_1.05.06_373	number of scans: 17
# 	volume: NL-HaNA_1.05.06_376	number of scans: 7
# 	volume: NL-HaNA_1.05.06_377	number of scans: 5
# 	volume: NL-HaNA_1.05.06_378	number of scans: 5
# 	volume: NL-HaNA_1.05.06_380	number of scans: 7
# 	volume: NL-HaNA_1.05.06_381	number of scans: 5
# 	volume: NL-HaNA_1.05.06_382	number of scans: 6
# 	volume: NL-HaNA_1.05.06_384	number of scans: 11
# 	volume: NL-HaNA_1.05.06_385	number of scans: 9
# 	volume: NL-HaNA_1.05.06_386	number of scans: 3
# 	volume: NL-HaNA_1.05.06_387A	number of scans: 3
# 	volume: NL-HaNA_1.05.06_388	number of scans: 7
# 	volume: NL-HaNA_1.05.06_389	number of scans: 8
# 	volume: NL-HaNA_1.05.06_392	number of scans: 3
# 	volume: NL-HaNA_1.05.06_394	number of scans: 5
# 	volume: NL-HaNA_1.05.06_395	number of scans: 7
# 	volume: NL-HaNA_1.05.06_399	number of scans: 7
# 	volume: NL-HaNA_1.05.06_40	number of scans: 146
# 	volume: NL-HaNA_1.05.06_405A	number of scans: 4
# 	volume: NL-HaNA_1.05.06_409	number of scans: 19
# 	volume: NL-HaNA_1.05.06_40A	number of scans: 126
# 	volume: NL-HaNA_1.05.06_41	number of scans: 164
# 	volume: NL-HaNA_1.05.06_414	number of scans: 7
# 	volume: NL-HaNA_1.05.06_415	number of scans: 7
# 	volume: NL-HaNA_1.05.06_416	number of scans: 3
# 	volume: NL-HaNA_1.05.06_42	number of scans: 5
# 	volume: NL-HaNA_1.05.06_426	number of scans: 11
# 	volume: NL-HaNA_1.05.06_43	number of scans: 3
# 	volume: NL-HaNA_1.05.06_44	number of scans: 672
# 	volume: NL-HaNA_1.05.06_45	number of scans: 488
# 	volume: NL-HaNA_1.05.06_452	number of scans: 87
# 	volume: NL-HaNA_1.05.06_453	number of scans: 3
# 	volume: NL-HaNA_1.05.06_454	number of scans: 6
# 	volume: NL-HaNA_1.05.06_456	number of scans: 5
# 	volume: NL-HaNA_1.05.06_457	number of scans: 9
# 	volume: NL-HaNA_1.05.06_46	number of scans: 18
# 	volume: NL-HaNA_1.05.06_462	number of scans: 97
# 	volume: NL-HaNA_1.05.06_464	number of scans: 154
# 	volume: NL-HaNA_1.05.06_467	number of scans: 3
# 	volume: NL-HaNA_1.05.06_469	number of scans: 5
# 	volume: NL-HaNA_1.05.06_471	number of scans: 3
# 	volume: NL-HaNA_1.05.06_472	number of scans: 5
# 	volume: NL-HaNA_1.05.06_476	number of scans: 5
# 	volume: NL-HaNA_1.05.06_478	number of scans: 59
# 	volume: NL-HaNA_1.05.06_479	number of scans: 142
# 	volume: NL-HaNA_1.05.06_479A	number of scans: 3
# 	volume: NL-HaNA_1.05.06_47B	number of scans: 3
# 	volume: NL-HaNA_1.05.06_48	number of scans: 48
# 	volume: NL-HaNA_1.05.06_481	number of scans: 21
# 	volume: NL-HaNA_1.05.06_482	number of scans: 3
# 	volume: NL-HaNA_1.05.06_483	number of scans: 7
# 	volume: NL-HaNA_1.05.06_485	number of scans: 16
# 	volume: NL-HaNA_1.05.06_487	number of scans: 3
# 	volume: NL-HaNA_1.05.06_488	number of scans: 11
# 	volume: NL-HaNA_1.05.06_489	number of scans: 3
# 	volume: NL-HaNA_1.05.06_49	number of scans: 126
# 	volume: NL-HaNA_1.05.06_496	number of scans: 7
# 	volume: NL-HaNA_1.05.06_50	number of scans: 7
# 	volume: NL-HaNA_1.05.06_501	number of scans: 7
# 	volume: NL-HaNA_1.05.06_502	number of scans: 2
# 	volume: NL-HaNA_1.05.06_503	number of scans: 13
# 	volume: NL-HaNA_1.05.06_51	number of scans: 13
# 	volume: NL-HaNA_1.05.06_515A	number of scans: 7
# 	volume: NL-HaNA_1.05.06_52	number of scans: 9
# 	volume: NL-HaNA_1.05.06_524	number of scans: 11
# 	volume: NL-HaNA_1.05.06_525	number of scans: 2
# 	volume: NL-HaNA_1.05.06_53	number of scans: 340
# 	volume: NL-HaNA_1.05.06_531	number of scans: 86
# 	volume: NL-HaNA_1.05.06_534	number of scans: 9
# 	volume: NL-HaNA_1.05.06_535	number of scans: 18
# 	volume: NL-HaNA_1.05.06_536	number of scans: 3
# 	volume: NL-HaNA_1.05.06_54	number of scans: 58
# 	volume: NL-HaNA_1.05.06_545A	number of scans: 32
# 	volume: NL-HaNA_1.05.06_549	number of scans: 3
# 	volume: NL-HaNA_1.05.06_555	number of scans: 7
# 	volume: NL-HaNA_1.05.06_557	number of scans: 7
# 	volume: NL-HaNA_1.05.06_56	number of scans: 88
# 	volume: NL-HaNA_1.05.06_562	number of scans: 5
# 	volume: NL-HaNA_1.05.06_564A	number of scans: 17
# 	volume: NL-HaNA_1.05.06_567	number of scans: 11
# 	volume: NL-HaNA_1.05.06_567A	number of scans: 74
# 	volume: NL-HaNA_1.05.06_57	number of scans: 15
# 	volume: NL-HaNA_1.05.06_572	number of scans: 3
# 	volume: NL-HaNA_1.05.06_573	number of scans: 3
# 	volume: NL-HaNA_1.05.06_574	number of scans: 33
# 	volume: NL-HaNA_1.05.06_577	number of scans: 8
# 	volume: NL-HaNA_1.05.06_578	number of scans: 26
# 	volume: NL-HaNA_1.05.06_579	number of scans: 19
# 	volume: NL-HaNA_1.05.06_583	number of scans: 36
# 	volume: NL-HaNA_1.05.06_585	number of scans: 3
# 	volume: NL-HaNA_1.05.06_59	number of scans: 3
# 	volume: NL-HaNA_1.05.06_6	number of scans: 11
# 	volume: NL-HaNA_1.05.06_60	number of scans: 15
# 	volume: NL-HaNA_1.05.06_606	number of scans: 9
# 	volume: NL-HaNA_1.05.06_607	number of scans: 4
# 	volume: NL-HaNA_1.05.06_608	number of scans: 3
# 	volume: NL-HaNA_1.05.06_61	number of scans: 5
# 	volume: NL-HaNA_1.05.06_613	number of scans: 5
# 	volume: NL-HaNA_1.05.06_617	number of scans: 7
# 	volume: NL-HaNA_1.05.06_62	number of scans: 89
# 	volume: NL-HaNA_1.05.06_63	number of scans: 7
# 	volume: NL-HaNA_1.05.06_64	number of scans: 3
# 	volume: NL-HaNA_1.05.06_65	number of scans: 9
# 	volume: NL-HaNA_1.05.06_66	number of scans: 21
# 	volume: NL-HaNA_1.05.06_67	number of scans: 5
# 	volume: NL-HaNA_1.05.06_674	number of scans: 214
# 	volume: NL-HaNA_1.05.06_676	number of scans: 3
# 	volume: NL-HaNA_1.05.06_677	number of scans: 6
# 	volume: NL-HaNA_1.05.06_679	number of scans: 5
# 	volume: NL-HaNA_1.05.06_683	number of scans: 13
# 	volume: NL-HaNA_1.05.06_689	number of scans: 7
# 	volume: NL-HaNA_1.05.06_69	number of scans: 22
# 	volume: NL-HaNA_1.05.06_690	number of scans: 23
# 	volume: NL-HaNA_1.05.06_691	number of scans: 22
# 	volume: NL-HaNA_1.05.06_7	number of scans: 5
# 	volume: NL-HaNA_1.05.06_70	number of scans: 14
# 	volume: NL-HaNA_1.05.06_703	number of scans: 11
# 	volume: NL-HaNA_1.05.06_708	number of scans: 3
# 	volume: NL-HaNA_1.05.06_709	number of scans: 14
# 	volume: NL-HaNA_1.05.06_71	number of scans: 21
# 	volume: NL-HaNA_1.05.06_710	number of scans: 7
# 	volume: NL-HaNA_1.05.06_711	number of scans: 17
# 	volume: NL-HaNA_1.05.06_712	number of scans: 21
# 	volume: NL-HaNA_1.05.06_713	number of scans: 246
# 	volume: NL-HaNA_1.05.06_714	number of scans: 27
# 	volume: NL-HaNA_1.05.06_72	number of scans: 15
# 	volume: NL-HaNA_1.05.06_720	number of scans: 10
# 	volume: NL-HaNA_1.05.06_721	number of scans: 20
# 	volume: NL-HaNA_1.05.06_722	number of scans: 53
# 	volume: NL-HaNA_1.05.06_723	number of scans: 75
# 	volume: NL-HaNA_1.05.06_724	number of scans: 59
# 	volume: NL-HaNA_1.05.06_727	number of scans: 26
# 	volume: NL-HaNA_1.05.06_728	number of scans: 16
# 	volume: NL-HaNA_1.05.06_729	number of scans: 19
# 	volume: NL-HaNA_1.05.06_73	number of scans: 7
# 	volume: NL-HaNA_1.05.06_730	number of scans: 23
# 	volume: NL-HaNA_1.05.06_731	number of scans: 115
# 	volume: NL-HaNA_1.05.06_740	number of scans: 22
# 	volume: NL-HaNA_1.05.06_748	number of scans: 159
# 	volume: NL-HaNA_1.05.06_749A	number of scans: 55
# 	volume: NL-HaNA_1.05.06_75	number of scans: 3
# 	volume: NL-HaNA_1.05.06_750A	number of scans: 43
# 	volume: NL-HaNA_1.05.06_757	number of scans: 11
# 	volume: NL-HaNA_1.05.06_76	number of scans: 7
# 	volume: NL-HaNA_1.05.06_771	number of scans: 10
# 	volume: NL-HaNA_1.05.06_781	number of scans: 5
# 	volume: NL-HaNA_1.05.06_784	number of scans: 7
# 	volume: NL-HaNA_1.05.06_8	number of scans: 16
# 	volume: NL-HaNA_1.05.06_801	number of scans: 5
# 	volume: NL-HaNA_1.05.06_808	number of scans: 308
# 	volume: NL-HaNA_1.05.06_809	number of scans: 5
# 	volume: NL-HaNA_1.05.06_812	number of scans: 416
# 	volume: NL-HaNA_1.05.06_813	number of scans: 83
# 	volume: NL-HaNA_1.05.06_814	number of scans: 5
# 	volume: NL-HaNA_1.05.06_876	number of scans: 79
# 	volume: NL-HaNA_1.05.06_878	number of scans: 4
# 	volume: NL-HaNA_1.05.06_879	number of scans: 11
# 	volume: NL-HaNA_1.05.06_880	number of scans: 9
# 	volume: NL-HaNA_1.05.06_881	number of scans: 3
# 	volume: NL-HaNA_1.05.06_882	number of scans: 4
# 	volume: NL-HaNA_1.05.06_883	number of scans: 3
# 	volume: NL-HaNA_1.05.06_884	number of scans: 3
# 	volume: NL-HaNA_1.05.06_885	number of scans: 7
# 	volume: NL-HaNA_1.05.06_886	number of scans: 2
# 	volume: NL-HaNA_1.05.06_887	number of scans: 3
# 	volume: NL-HaNA_1.05.06_888	number of scans: 3
# 	volume: NL-HaNA_1.05.06_889	number of scans: 11
# 	volume: NL-HaNA_1.05.06_890	number of scans: 9
# 	volume: NL-HaNA_1.05.06_891	number of scans: 5
# 	volume: NL-HaNA_1.05.06_892	number of scans: 5
# 	volume: NL-HaNA_1.05.06_893	number of scans: 5
# 	volume: NL-HaNA_1.05.06_894	number of scans: 71
# 	volume: NL-HaNA_1.05.06_9	number of scans: 21
# 	volume: NL-HaNA_1.05.06_901	number of scans: 17
# 	volume: NL-HaNA_1.05.06_902	number of scans: 17
# 	volume: NL-HaNA_1.05.06_903	number of scans: 15
# 	volume: NL-HaNA_1.05.06_904	number of scans: 236
# 	volume: NL-HaNA_1.05.06_905	number of scans: 2
# 	volume: NL-HaNA_1.05.06_907	number of scans: 3
# 	volume: NL-HaNA_1.05.06_918	number of scans: 9
# 	volume: NL-HaNA_1.05.06_921	number of scans: 9
# 	volume: NL-HaNA_1.05.06_922	number of scans: 2
# 	volume: NL-HaNA_1.05.06_923	number of scans: 7
# 	volume: NL-HaNA_1.05.06_924	number of scans: 3
# 	volume: NL-HaNA_1.05.06_925	number of scans: 3
# 	volume: NL-HaNA_1.05.06_926	number of scans: 8
# 	volume: NL-HaNA_1.05.06_928	number of scans: 13
# 	volume: NL-HaNA_1.05.06_929	number of scans: 16
# 	volume: NL-HaNA_1.05.06_929A	number of scans: 3
# 	volume: NL-HaNA_1.05.06_929B	number of scans: 8
# 	volume: NL-HaNA_1.05.06_930	number of scans: 11
# 	volume: NL-HaNA_1.05.06_931	number of scans: 5
# 	volume: NL-HaNA_1.05.06_932	number of scans: 39
# 	volume: NL-HaNA_1.05.06_933	number of scans: 3
# 	volume: NL-HaNA_1.05.06_934	number of scans: 44
# 	volume: NL-HaNA_1.05.06_936	number of scans: 18
# 	volume: NL-HaNA_1.05.06_937	number of scans: 7
# 	volume: NL-HaNA_1.05.06_938	number of scans: 5
# 	volume: NL-HaNA_1.05.06_939	number of scans: 13
# 	volume: NL-HaNA_1.05.06_940	number of scans: 5
# 	volume: NL-HaNA_1.05.06_941	number of scans: 5
# 	volume: NL-HaNA_1.05.06_942	number of scans: 11
# 	volume: NL-HaNA_1.05.06_946	number of scans: 4
# 	volume: NL-HaNA_1.05.06_95	number of scans: 17
# 	volume: NL-HaNA_1.05.06_951	number of scans: 5
# 	volume: NL-HaNA_1.05.06_954	number of scans: 5
# 	volume: NL-HaNA_1.05.06_955	number of scans: 6
# 	volume: NL-HaNA_1.05.06_96	number of scans: 2
# 	volume: NL-HaNA_1.05.06_963	number of scans: 5
# 	volume: NL-HaNA_1.05.06_964	number of scans: 4
# 	volume: NL-HaNA_1.05.06_965	number of scans: 13
# 	volume: NL-HaNA_1.05.06_97	number of scans: 9
# 	volume: NL-HaNA_1.05.06_970	number of scans: 29
# 	volume: NL-HaNA_1.05.06_971	number of scans: 23
# 	volume: NL-HaNA_1.05.06_972	number of scans: 41
# 	volume: NL-HaNA_1.05.06_973	number of scans: 8
# 	volume: NL-HaNA_1.05.06_975	number of scans: 7
# 	volume: NL-HaNA_1.05.06_978	number of scans: 3
# 	volume: NL-HaNA_1.05.06_979	number of scans: 13
# 	volume: NL-HaNA_1.05.06_98	number of scans: 17
# 	volume: NL-HaNA_1.05.06_980	number of scans: 19
# 	volume: NL-HaNA_1.05.06_981	number of scans: 5
# 	volume: NL-HaNA_1.05.06_983	number of scans: 312
# 	volume: NL-HaNA_1.05.06_983A	number of scans: 102
# 	volume: NL-HaNA_1.05.06_984	number of scans: 7
# 	volume: NL-HaNA_1.05.06_99	number of scans: 40

# %% [markdown]
# It turns out that the Notarial archive zip file only contains a single zip file with a volume of 630 PageXML files, while the West Indische Stukken has many smaller volumes.

# %%
archive_id = 'NL-AsnDA_0114.11'
archive_file = '../data/HTR results DA 0114.11 PAGE.zip'
archive_stats = defaultdict(int)

for page_fileinfo, page_data in read_page_archive_files(archive_file, 
                                                        show_progress=True):
    scan = parse_pagexml_file(pagexml_file=page_fileinfo['archived_filename'], pagexml_data=page_data)
    scan_stats = scan.stats
    for field in scan_stats:
        archive_stats[field] += scan_stats[field]

archive_stats
# Out:
# extracting PageXML files from ../data/HTR results DA 0114.11 PAGE.zip: 630it [00:19, 32.18it/s]
# defaultdict(int,
#             {'lines': 56700,
#              'words': 238926,
#              'text_regions': 2484,
#              'columns': 0,
#              'extra': 0,
#              'pages': 0})

# %% [markdown]
# The 630 PageXML files in the dataset of the notarial archive of D.A.M. de Fremery contains close to 240,000 words.

# %% [markdown]
# ## Transforming XML into plain text line format files
#
# If you want to work on the text of the PageXML files, it can be useful to make a plain text format that is faster to process and uses less memory. The PageXML tools package contains functionality to extract the text lines from PageXML files into a simple tab-separated value format.

# %%
from pagexml.helper.text_helper import make_line_format_file, make_page_extractor


for archive in archives:
    line_tsv_file = f"../data/line_format-{archive['id']}.tsv.gz"
    page_extractor = make_page_extractor(archive['file'])
    make_line_format_file(page_extractor, line_tsv_file, add_bounding_box=True)

# %%
from pagexml.helper.text_helper import LineReader

line_tsv_file = '../data/line_format-NL-HaNA_1.05.06.tsv.gz'

reader = LineReader(pagexml_line_files=line_tsv_file)
for line in reader:
    print(line)
    break
# Out:
# {'doc_id': 'NL-HaNA_1.05.06_1_0001.jpg', 'textregion_id': 'r1', 'line_id': 'r1l1', 'text': 'Jieem — Nederland', 'doc_box': '0,0,2522,3957', 'textregion_box': '120,152,2333,3493', 'line_box': '586,136,1108,113'}
